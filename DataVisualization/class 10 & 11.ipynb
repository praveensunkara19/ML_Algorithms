# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# PIE CHART
values = [57,20,10,4,9]
x = ['Nitrogen','oxygen','co2','Hydrogen','other gases']
col2 = ['pink','red','cyan','yellow','blue']
plt.pie(values,labels=x,colors = col2, shadow=True,explode = [0,0,0,0,0.4],counterclock = False,startangle = 90,autopct = '%1.2f%%')
plt.show()

# %%
import numpy as np
x = np.random.normal(130,10,200)       #maximum values are around 130 # create 200 values#     10 - standard deviation
plt.hist(x,color='red')
plt.show()

# %%
# PANDAS - Data analysis library
# datasets - files / useful information used for analysis

# %%
# series    - 1 dimensional(single column), uses indexing   (very similar to lists,numpy arrays)

# dataframe - 2 dimensional(generally multiple columns), uses indexing   (table like structure)

# %%
import pandas as pd

# %%
data = np.array(['aa','bb','cc','dd','ee'])
data
s1 = pd.Series(data)

# %%
s1
# Out:
# 0    aa
# 1    bb
# 2    cc
# 3    dd
# 4    ee
# dtype: object

# %%
n1 = np.array(['hello world'])
n1
# Out:
# array(['hello world'], dtype='<U11')

# %%
# "hello world"
#                                  DATATYPE
# core python (list/tuple)         str
# numpy       (arrays)             unicode character string <U11
# pandas      (series)             object

# %%
data = np.array([1,3,4,5,6,7.3,8,9])
data
s2 = pd.Series(data)
s2
# Out:
# 0    1.0
# 1    3.0
# 2    4.0
# 3    5.0
# 4    6.0
# 5    7.3
# 6    8.0
# 7    9.0
# dtype: float64

# %%
type(s2)
# Out:
# pandas.core.series.Series

# %%
# df - dataframe
df = pd.DataFrame(data)
df
# Out:
#      0
# 0  1.0
# 1  3.0
# 2  4.0
# 3  5.0
# 4  6.0
# 5  7.3
# 6  8.0
# 7  9.0

# %%
df = pd.read_table("/content/demo.txt")
df
# Out:
#    Sl No. Firstname Lastname
# 0       1         A        a
# 1       2         B        b
# 2       3         C        c
# 3       4         D        d
# 4       5         E        e
# 5       6         F        f
# 6       7         G        g

# %%
# https://www.kaggle.com/datasets/mjamilmoughal/fruits-with-colors-dataset

# %%
#creating dataframe using a raw link
df = pd.read_table("https://storage.googleapis.com/kagglesdsdata/datasets/9590/13660/fruit_data_with_colors.txt?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20220425%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20220425T142717Z&X-Goog-Expires=259199&X-Goog-SignedHeaders=host&X-Goog-Signature=...")
df

# %%
#creating dataframe using a raw link from github
df = pd.read_table("https://raw.githubusercontent.com/arib168/data/main/fruit_data_with_colors.txt")
df

# %%
#creating dataframe using the file
df = pd.read_table('/content/fruit_data_with_colors.txt')
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info() #gives complete information about the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_label    59 non-null     int64
#  1   fruit_name     59 non-null     object
#  2   fruit_subtype  59 non-null     object
#  3   mass           59 non-null     int64
#  4   width          59 non-null     float64
#  5   height         59 non-null     float64
#  6   color_score    59 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 3.4+ KB

# %%
df.isnull().sum()  #sum of all the null value counts
# NaN - Not a number (null value)
# Out:
# fruit_label      0
# fruit_name       0
# fruit_subtype    0
# mass             0
# width            0
# height           0
# color_score      0
# dtype: int64

# %%
# df.dropna()  #deletes any null values if they are present

# %%
df.columns #prints all column names
# Out:
# Index(['fruit_label', 'fruit_name', 'fruit_subtype', 'mass', 'width', 'height',
#        'color_score'],
#       dtype='object')

# %%
df.shape  #rows,columns
# Out:
# (59, 7)

# %%
df.size #rows * columns = total no. of values in the df
# Out:
# 413

# %%
df.describe()   #summary statistics of the dataframe (numerical columns)
# Out:
#        fruit_label        mass      width     height  color_score
# count    59.000000   59.000000  59.000000  59.000000    59.000000
# mean      2.542373  163.118644   7.105085   7.693220     0.762881
# std       1.208048   55.018832   0.816938   1.361017     0.076857
# min       1.000000   76.000000   5.800000   4.000000     0.550000
# 25%       1.000000  140.000000   6.600000   7.200000     0.720000
# 50%       3.000000  158.000000   7.200000   7.600000     0.750000
# 75%       4.000000  177.000000   7.500000   8.200000     0.810000
# max       4.000000  362.000000   9.600000  10.500000     0.930000

# %%
df.head()  #prints only first 5 rows
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
df.head(7)
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79
# 5            2   mandarin      mandarin    80    5.8     4.3         0.77
# 6            2   mandarin      mandarin    80    5.9     4.3         0.81

# %%
df.tail()  #prints last 5 rows
# Out:
#     fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 54            4      lemon       unknown   116    6.1     8.5         0.71
# 55            4      lemon       unknown   116    6.3     7.7         0.72
# 56            4      lemon       unknown   116    5.9     8.1         0.73
# 57            4      lemon       unknown   152    6.5     8.5         0.72
# 58            4      lemon       unknown   118    6.1     8.1         0.70

# %%
df.tail(8)
# Out:
#     fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 51            4      lemon       unknown   116    6.0     7.5         0.72
# 52            4      lemon       unknown   118    5.9     8.0         0.72
# 53            4      lemon       unknown   120    6.0     8.4         0.74
# 54            4      lemon       unknown   116    6.1     8.5         0.71
# 55            4      lemon       unknown   116    6.3     7.7         0.72
# 56            4      lemon       unknown   116    5.9     8.1         0.73
# 57            4      lemon       unknown   152    6.5     8.5         0.72
# 58            4      lemon       unknown   118    6.1     8.1         0.70

# %%
df[25:30]   #slicing the dataframe     # 25 - inclusive   #30 - exclusive
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 25            3     orange     spanish_jumbo   356    9.2     9.2         0.75
# 26            3     orange     spanish_jumbo   362    9.6     9.2         0.74
# 27            3     orange  selected_seconds   204    7.5     9.2         0.77
# 28            3     orange  selected_seconds   140    6.7     7.1         0.72
# 29            3     orange  selected_seconds   160    7.0     7.4         0.81

# %%
# df[25:30,0:3]  #this gives an error for the columns slicing

# %%
df.iloc[25:30,0:3]  #df.iloc - integer location based indexing for selection by position
# Out:
#     fruit_label fruit_name     fruit_subtype
# 25            3     orange     spanish_jumbo
# 26            3     orange     spanish_jumbo
# 27            3     orange  selected_seconds
# 28            3     orange  selected_seconds
# 29            3     orange  selected_seconds

# %%
df.iloc[25:30,3:7]
# Out:
#     mass  width  height  color_score
# 25   356    9.2     9.2         0.75
# 26   362    9.6     9.2         0.74
# 27   204    7.5     9.2         0.77
# 28   140    6.7     7.1         0.72
# 29   160    7.0     7.4         0.81

# %%
df.iloc[10:20,[0,3,4,5,6]]
# Out:
#     fruit_label  mass  width  height  color_score
# 10            1   166    6.9     7.3         0.93
# 11            1   172    7.1     7.6         0.92
# 12            1   154    7.0     7.1         0.88
# 13            1   164    7.3     7.7         0.70
# 14            1   152    7.6     7.3         0.69
# 15            1   156    7.7     7.1         0.69
# 16            1   156    7.6     7.5         0.67
# 17            1   168    7.5     7.6         0.73
# 18            1   162    7.5     7.1         0.83
# 19            1   162    7.4     7.2         0.85

# %%
df.iloc[10:20,[0,2,6,4]]
# Out:
#     fruit_label     fruit_subtype  color_score  width
# 10            1          braeburn         0.93    6.9
# 11            1          braeburn         0.92    7.1
# 12            1          braeburn         0.88    7.0
# 13            1  golden_delicious         0.70    7.3
# 14            1  golden_delicious         0.69    7.6
# 15            1  golden_delicious         0.69    7.7
# 16            1  golden_delicious         0.67    7.6
# 17            1  golden_delicious         0.73    7.5
# 18            1       cripps_pink         0.83    7.5
# 19            1       cripps_pink         0.85    7.4

# %%
df.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
# fname = df.fruit_name.unique()

fname = df['fruit_name'].unique()
fname
# Out:
# array(['apple', 'mandarin', 'orange', 'lemon'], dtype=object)

# %%
fname1 = df['fruit_name'].nunique()  #count of the number of unique elements
fname1
# Out:
# 4

# %%
# to know the count of each of the unique values
fsize = df.groupby('fruit_name',sort=False).size()
fsize
# Out:
# fruit_name
# apple       19
# mandarin     5
# orange      19
# lemon       16
# dtype: int64

# %%
plt.bar(fname,fsize)
# Out:
# <BarContainer object of 4 artists>

# %%
df['fruit_name'].value_counts()
# Out:
# apple       19
# orange      19
# lemon       16
# mandarin     5
# Name: fruit_name, dtype: int64

# %%
df['fruit_name'].value_counts().plot(kind = 'bar') #pandas plotting

# %%
df['fruit_name'].value_counts().plot(kind = 'line') #pandas plotting

# %%
df['fruit_name'].value_counts().plot(kind = 'pie') #pandas plotting

# %%
height = df['height']
width = df['width']

# %%
plt.scatter(height,width,c=height,s=100,cmap='seismic')

# %%
df.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
df = df.drop(['fruit_label'],axis = 1 )  #dropping a column from the dataframe
df.head()
# Out:
#   fruit_name fruit_subtype  mass  width  height  color_score
# 0      apple  granny_smith   192    8.4     7.3         0.55
# 1      apple  granny_smith   180    8.0     6.8         0.59
# 2      apple  granny_smith   176    7.4     7.2         0.60
# 3   mandarin      mandarin    86    6.2     4.7         0.80
# 4   mandarin      mandarin    84    6.0     4.6         0.79

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_name     59 non-null     object
#  1   fruit_subtype  59 non-null     object
#  2   mass           59 non-null     int64
#  3   width          59 non-null     float64
#  4   height         59 non-null     float64
#  5   color_score    59 non-null     float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 2.9+ KB

# %%
df['mass'].max()
# Out:
# 362

# %%
df['mass'].min()
# Out:
# 76

# %%
df.rename(columns = {'fruit_subtype':'Fruit Type'},inplace=True) #to rename the columns
df.head()
# Out:
#   fruit_name    Fruit Type  mass  width  height  color_score
# 0      apple  granny_smith   192    8.4     7.3         0.55
# 1      apple  granny_smith   180    8.0     6.8         0.59
# 2      apple  granny_smith   176    7.4     7.2         0.60
# 3   mandarin      mandarin    86    6.2     4.7         0.80
# 4   mandarin      mandarin    84    6.0     4.6         0.79

# %%
# np.where() - syntax    (similar to if conditions)

# %%
df = pd.read_csv('/content/Book1.csv')
df
# Out:
#    SL No. capital small
# 0       1     AAA   aaa
# 1       2     BBB   bbb
# 2       3     CCC   ccc
# 3       4     DDD   ddd
# 4       5     EEE   eee
# 5       6     FFF   fff
# 6       7     GGG   ggg
# 7       8     HHH   hhh
# 8       9     III   iii
# 9      10     JJJ   jjj

# %%
# .csv    - comma separated values
# .tsv    - tab separated values
# .json   - javascript object notation
# .xlsx   - excel spreadsheet
# .txt    - text document
# .sql    - structured query language
# .html   - hypertext markup langauge
