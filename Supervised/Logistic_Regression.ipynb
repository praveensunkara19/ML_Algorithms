# %% [markdown]
# Logistic Regression is a classifiction algorithm
#
# it is Binary Classification
#
# ### it uses the the sigmoid function(returns the the input into values b/w 0 and 1)
#
#                 Linear function                                                 Sigmoid function
# ![image.png](attachment:image.png)

# %% [markdown]
# Formula
# S(x)= 1/(1+e^{-x})
#
#
# S(x)	=	sigmoid function
# e	=	Euler's number

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\prave\\OneDrive\\Desktop\\Git\\MachineLearning\\Datasets\\insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
x = df[['age']]
y = df['bought_insurance']

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y,marker='+',c='r')

# %%
df.shape
# Out:
# (27, 2)

# %%
print(x.ndim)
print(y.ndim)
# Out:
# 2
# 1

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
print(len(x_train))
print(len(x_test))
print(len(y_train))
print(len(y_test))
# Out:
# 21
# 6
# 21
# 6

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg  = LogisticRegression()

# %%
log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = log_reg.predict(x_test)

y_pred
# Out:
# array([1, 1, 1, 1, 0, 1], dtype=int64)

# %%
pd.DataFrame({'actual': y_test,'predicted': y_pred})
# Out:
#     actual  predicted
# 15       1          1
# 6        0          1
# 24       1          1
# 25       1          1
# 1        0          0
# 22       1          1

# %%
log_reg.score(x_train,y_train)
# Out:
# 0.9047619047619048

# %%
from sklearn.metrics import accuracy_score,r2_score,mean_squared_error
print('accuracy', accuracy_score(y_test,y_pred))
# Out:
# 0.8333333333333334

# %%
prob = log_reg.predict_proba(x_test)  #gives yes no
prob
# Out:
# array([[0.06854422, 0.93145578],
#        [0.06854422, 0.93145578],
#        [0.13745606, 0.86254394],
#        [0.07909319, 0.92090681],
#        [0.88358822, 0.11641178],
#        [0.42770862, 0.57229138]])

# %%
pd.DataFrame({'yes':prob[:,0],'no':prob[:,1],'y_pred':y_pred})
# Out:
#         yes        no  y_pred
# 0  0.068544  0.931456       1
# 1  0.068544  0.931456       1
# 2  0.137456  0.862544       1
# 3  0.079093  0.920907       1
# 4  0.883588  0.116412       0
# 5  0.427709  0.572291       1

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)
plt.plot(y_test,y_pred)

# %%
# This is because the dataset is small
