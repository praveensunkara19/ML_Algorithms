# %%
# jupyter is the notebook to write python code
# colab is the online version of jupyter
# jupyter works on localhost
# colab works on cloud (google compute engine backend)(notebooks are saved in gooogle drive)
# most of the libraries and frameworks are preinstalled in google colaboratory (that's why it is preferred)

# %%
# .py - python file
# .ipynb - interactive python notebook

# %%
print("HELLO WORLD!")
# Out:
# HELLO WORLD!

# %% [markdown]
# **PYTHON INTRODUCTION**

# %%
a = 1

# %%
type(a)
# Out:
# int

# %%
a = 5

# %%
type(a)
# Out:
# int

# %%
print(a)
# Out:
# 5

# %%
print(type(a))    # actual way to print (this is how you get the output in .py files)  #single line comment
print(a)
# Out:
# <class 'int'>
# 5

# %%
a
# Out:
# 5

# %%
type(a)
# Out:
# int

# %%
b = 3.56

# %%
type(b)
# Out:
# float

# %%
print(a)
'''
print(b)       This is a multi line line comment
print(type(a))
'''
print(type(b))
# Out:
# 5
# <class 'float'>

# %%
# # single line comments
# 34uwegfydsu
# fuasvbhj
# wafuvsdzjxhc ngfrsf
# evwsuhcj'
# wsdv
# wsdciv
# wdscix;fwcsx
# ctrl + a    and then ctrl+/ (adds single line comments to all the lines in the cell)
